# %%
import pandas as pd

# Creating a mock dataset
data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] * 2,
    'Product': ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',
                'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'],
    'Sales': [300, 400, 350, 600, 500, 700, 800, 650, 700, 750, 800, 850,
              200, 300, 250, 450, 350, 650, 580, 600, 590, 700, 850, 900]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('sales_data.csv', index=False)

# %%
# Loading the dataset
df = pd.read_csv('sales_data.csv')

# Exploring the dataset
print(df.head())
print(df.describe())
print(df.info())
# Out:
#   Month Product  Sales
# 0   Jan       A    300
# 1   Feb       A    400
# 2   Mar       A    350
# 3   Apr       A    600
# 4   May       A    500
#             Sales
# count   24.000000
# mean   575.833333
# std    208.408392
# min    200.000000
# 25%    387.500000
# 50%    600.000000
# 75%    712.500000
# max    900.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    24 non-null     object
#  1   Product  24 non-null     object
#  2   Sales    24 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 708.0+ bytes
# None

# %%
# Total sales per product
total_sales = df.groupby('Product')['Sales'].sum().reset_index()
print(total_sales)
# Out:
#   Product  Sales
# 0       A   7400
# 1       B   6420

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a bar plot for total sales per product
plt.figure(figsize=(10, 6))
sns.barplot(x='Product', y='Sales', data=total_sales)
plt.title('Total Sales per Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# Create a time series line plot for sales by month and product
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Month', y='Sales', hue='Product', marker='o')
plt.title('Monthly Sales per Product')
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid()
plt.show()
